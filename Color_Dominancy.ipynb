# %% [markdown]
# <a href="https://colab.research.google.com/github/AQadir44/Dominant_Color/blob/main/Color_Dominancy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Identify the Color dominancy in an Image

# %%
# !pip install colormap
# !pip install easydev
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting colormap
#   Downloading colormap-1.0.4.tar.gz (17 kB)
# Building wheels for collected packages: colormap
#   Building wheel for colormap (setup.py) ... done
#   Created wheel for colormap: filename=colormap-1.0.4-py3-none-any.whl size=15637 sha256=6ac5b8b3737c7fb897ad9fe30da83cbd7720ef134f72134cb829ccc8d4d8a854
#   Stored in directory: /root/.cache/pip/wheels/71/35/4b/259c328e39ede29b184e4ffe4443bcc2be4e475178a83794c3
# Successfully built colormap
# Installing collected packages: colormap
# Successfully installed colormap-1.0.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting easydev
#   Downloading easydev-0.12.0.tar.gz (47 kB)
#      |████████████████████████████████| 47 kB 3.4 MB/s
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from easydev) (4.8.0)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->easydev) (0.7.0)
# Building wheels for collected packages: easydev
#   Building wheel for easydev (setup.py) ... done
#   Created wheel for easydev: filename=easydev-0.12.0-py3-none-any.whl size=64231 sha256=02a05c25c15d60126d52f330c7d0ffc81ce46651e8680872df5286861e4caca9
#   Stored in directory: /root/.cache/pip/wheels/82/ab/83/fdfc4017ea44a585b6754752cc5f63f2d0d63fcc1317e7174b
# Successfully built easydev
# Installing collected packages: colorlog, colorama, easydev
# Successfully installed colorama-0.4.6 colorlog-6.7.0 easydev-0.12.0

# %%
# !git clone https://github.com/AQadir44/Dominant_Color.git
# Out:
# Cloning into 'Dominant_Color'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (7/7), done.

# %%
import PIL
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
import cv2
from colormap import rgb2hex

# %%
def read_image(img):
  #Read the Image
  try:
      print("Read The Image")
      #Read the image
      image = cv2.imread(img)

      print("Converting the Image")
      # Convert the Image into the RGB (Pil read the image in BGR)
      img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

      return img

  except Exception as e:
    return str(e)

# %%
def reshaping_image(img):
  try:
    #COnvert Image from 3D to 2D
    img = img.reshape((img.shape[0] * img.shape[1], 3))
    return img
  except Exception as e:
    return str(e)

# %%
def Kmeans_CLuster(img , cluster):
  #REad Image
      image_read = read_image(img)

      #Reshape Image
      reshape_img = reshaping_image(image_read)


      #Applying Kmeans for the Color Extraction in the form of cluster
      print("Fitting in The KMean Algorithm to identify the Colors CLuster")
      kmeans = MiniBatchKMeans(n_clusters = cluster)
      kmeans.fit(reshape_img)

      #the cluster centers are our dominant colors.
      colors = kmeans.cluster_centers_
      #save labels
      labels = kmeans.labels_

      #returning after converting to integer from float
      return colors  , labels

# %%
def plot_graph(cluster , labels , colors):
        print("Creating the Graph : ")

        #Calculating the Color Percent from the labels
        percent=[]
        labels=list(labels)
        for i in range(cluster):
          j=labels.count(i)
          j=(j/(len(labels)) )*100
          percent.append(j)

        #for RGB to HEX
        df_color_up = []
        for i in range(cluster):

            #getting rgb values
            r = colors[i][0]
            g = colors[i][1]
            b = colors[i][2]

            #convert RGB to HEX code
            df_color_up.append(rgb2hex(int(r),int(g),int(b)))


        #Ceating Dataframe for the Pie CHart
        data = pd.DataFrame(zip(df_color_up , percent ) , columns = ['color','percent'] )

        # Plotting Donut Chart
        plt.figure(figsize=(12,8))
        plt.pie(data['percent'],
        colors = data['color'],
        labels=data['color'],
        labeldistance= 1.05,
        autopct='%1.1f%%')
        plt.title('Different Color Chart')
        circle = plt.Circle( (0,0), 0.7, color='white')
        p=plt.gcf()
        p.gca().add_artist(circle)
        plt.show()

# %%
def masking_img(img):
    # Read image
    img = cv2.imread(img)
    hh, ww = img.shape[:2]

    # threshold on white
    # Define lower and uppper limits
    lower = np.array([200, 200, 200])
    upper = np.array([255, 255, 255])

    # Create mask to only select black
    thresh = cv2.inRange(img, lower, upper)

    # apply morphology
    # kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (20,20))
    morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, (20,20))

    # invert morp image
    mask = 255 - morph

    # apply mask to image
    result = cv2.bitwise_and(img, img, mask=mask)


    # Convert image to image gray
    tmp = cv2.cvtColor(result, cv2.COLOR_BGR2GRAY)

    # Applying thresholding technique
    _, alpha = cv2.threshold(tmp, 25, 255, cv2.THRESH_BINARY )
    # _, alpha  = cv2.adaptiveThreshold(result,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,11,2)

    # Using cv2.split() to split channels
    # of coloured image
    b, g, r = cv2.split(result)

    # Making list of Red, Green, Blue
    # Channels and alpha
    rgba = [b, g, r, alpha]

    # Using cv2.merge() to merge rgba
    # into a coloured/multi-channeled image
    dst = cv2.merge(rgba, 4)

    # Writing and saving to a new image
    cv2.imwrite("gfg_white.png", dst)

# %%
def Start_Task(img , cluster):
  print("Original Image")

  colors , labels  = Kmeans_CLuster(img , cluster)

  print("Dominat Color In The Image")
  plot_graph(cluster,labels,colors)

  print("Masking the Image For Better Color Dominancy")
  masking_img(img)

  colors , labels  = Kmeans_CLuster("gfg_white.png" , cluster)

  print("Dominat Color In The Masking Image")
  plot_graph(cluster,labels,colors)

# %% [markdown]
# ![Image.jpeg](data:image/jpeg;base64,...)

# %%
Start_Task('/content/Dominant_Color/Images/Image.jpeg' , 20)
# Out:
# Original Image
# Read The Image
# Converting the Image
# Fitting in The KMean Algorithm to identify the Colors CLuster
# Dominat Color In The Image
# Creating the Graph :
# Masking the Image For Better Color Dominancy
# Read The Image
# Converting the Image
# Fitting in The KMean Algorithm to identify the Colors CLuster
# Dominat Color In The Masking Image
# Creating the Graph :

# %% [markdown]
# #Test Image 1

# %% [markdown]
# ![testimage.jpg](data:image/jpeg;base64,...)

# %%
Start_Task('/content/Dominant_Color/Images/testimage.jpg' , 10)
# Out:
# Original Image
# Read The Image
# Converting the Image
# Fitting in The KMean Algorithm to identify the Colors CLuster
# Dominat Color In The Image
# Creating the Graph :
# Masking the Image For Better Color Dominancy
# Read The Image
# Converting the Image
# Fitting in The KMean Algorithm to identify the Colors CLuster
# Dominat Color In The Masking Image
# Creating the Graph :

# %% [markdown]
# #Test Image 2

# %% [markdown]
# ![test_image2.jpg](data:image/jpeg;base64,...)

# %%
Start_Task('/content/Dominant_Color/Images/test_image2.jpg' , 10)
# Out:
# Original Image
# Read The Image
# Converting the Image
# Fitting in The KMean Algorithm to identify the Colors CLuster
# Dominat Color In The Image
# Creating the Graph :
# Masking the Image For Better Color Dominancy
# Read The Image
# Converting the Image
# Fitting in The KMean Algorithm to identify the Colors CLuster
# Dominat Color In The Masking Image
# Creating the Graph :

# %% [markdown]
# #Test Image 3

# %% [markdown]
# ![test_image3.jpg](data:image/jpeg;base64,...)

# %%
Start_Task('/content/Dominant_Color/Images/test_image3.jpg' , 10)
# Out:
# Original Image
# Read The Image
# Converting the Image
# Fitting in The KMean Algorithm to identify the Colors CLuster
# Dominat Color In The Image
# Creating the Graph :
# Masking the Image For Better Color Dominancy
# Read The Image
# Converting the Image
# Fitting in The KMean Algorithm to identify the Colors CLuster
# Dominat Color In The Masking Image
# Creating the Graph :
